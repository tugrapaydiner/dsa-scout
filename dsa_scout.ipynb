# %% [markdown]
# # DSA-Scout Reproduction Notebook
#
# Minimal reproduction notebook for running the packaged study and inspecting the primary artifacts.

# %%
from dsa_scout.experiment import run_full_study

summary = run_full_study(training_steps=2000, max_length=1024)
summary["summary_stats"]["middle_layer_top8"]

# %%
from IPython.display import Image, display

# %%
for path in [
    "plots/01_oracle_heatmap.png",
    "plots/03_recall_by_layer.png",
    "plots/04_recall_vs_k.png",
]:
    display(Image(filename=path))

# %%
summary["summary_stats"]["hybrid_deltas"]

# %% [markdown]
# See `README.md`, `docs/METHODS.md`, `docs/DATA.md`, `results/summary_stats.json`, and `results/metadata.json` for the full writeup and audit trail.
